# %% [markdown]
# # Weevil manuscript
# Community assembly and diversification in a species‐rich radiation of island weevils (Coleoptera: Cratopini)
# https://onlinelibrary.wiley.com/doi/abs/10.1111/jbi.13393

# %%
import pandas as pd
import numpy as np
import os
from scipy.stats import entropy

metadata_df = pd.read_csv("Metadata/Supplementary_names.csv", index_col=0)
metadata_df = metadata_df.fillna("Mauritius")
metadata_df
# Out:
#            Exclude                 Organism                     Site  \
# Sample
# T-Reu_2367      No     Cratopopsis_alluaudi       Plaine_des_Gregues
# T-Reu_3153      No     Cratopopsis_alluaudi                Les_Makes
# T-Reu_3812      No     Cratopopsis_alluaudi  Sentier_Trophee_Mondial
# T-Reu_4047      No     Cratopopsis_alluaudi                Les_Makes
# T-Reu_4056      No     Cratopopsis_alluaudi                Les_Makes
# T-Reu_4057      No     Cratopopsis_alluaudi                Les_Makes
# T-Reu_4058      No     Cratopopsis_alluaudi                Les_Makes
# T-Reu_4343      No     Cratopopsis_alluaudi                Cap_Blanc
# T-Reu_4374      No     Cratopopsis_alluaudi                Cap_Blanc
# T-Reu_4396      No     Cratopopsis_alluaudi                Cap_Blanc
# T-Reu_4458      No     Cratopopsis_alluaudi                Cap_Blanc
# T-Reu_81        No     Cratopopsis_alluaudi                  Bayonne
# T-Reu_3458      No     Cratopopsis_antiquus              Piton_Mahot
# T-Reu_3459      No     Cratopopsis_antiquus              Piton_Mahot
# T-Reu_3460      No     Cratopopsis_antiquus              Piton_Mahot
# T-Reu_3462      No     Cratopopsis_antiquus              Piton_Mahot
# T-Reu_3465      No     Cratopopsis_antiquus          Piton_Hyacinthe
# T-Reu_3467      No     Cratopopsis_antiquus          Piton_Hyacinthe
# T-Reu_3471      No     Cratopopsis_antiquus          Piton_Hyacinthe
# T-Reu_3522      No     Cratopopsis_antiquus          Piton_Hyacinthe
# T-Reu_3526      No     Cratopopsis_antiquus          Piton_Hyacinthe
# T-Reu_3530     Yes     Cratopopsis_antiquus          Piton_Hyacinthe
# T-Reu_3605      No     Cratopopsis_antiquus          Foret_de_Bebour
# T-Reu_4265      No     Cratopopsis_antiquus         Foret_de_Bel_Air
# T-Reu_3461      No     Cratopopsis_bistigma              Piton_Mahot
# T-Reu_3491      No     Cratopopsis_bistigma          Piton_Hyacinthe
# T-Reu_4918      No     Cratopopsis_bistigma                 Le_Block
# T-Reu_80        No     Cratopopsis_bistigma                  Bayonne
# T-Reu_225       No    Cratopopsis_coquereli                  Volcano
# T-Reu_227       No    Cratopopsis_coquereli                  Volcano
# ...            ...                      ...                      ...
# T-Mau_3890     Yes        Cratopus_vulgaris                 Le_Pouce
# T-Mau_3894      No        Cratopus_vulgaris              Camp_Thorel
# T-Mau_3895      No        Cratopus_vulgaris              Camp_Thorel
# T-Mau_3918      No        Cratopus_vulgaris                   Gorges
# T-Mau_3921      No        Cratopus_vulgaris           Trois_Mamelles
# T-Mau_3922      No        Cratopus_vulgaris           Trois_Mamelles
# T-Mau_3923      No        Cratopus_vulgaris           Trois_Mamelles
# T-Mau_73        No        Cratopus_vulgaris                 Machabee
# T-Mau_84        No        Cratopus_vulgaris              Pigeon_wood
# T-Mau_93        No        Cratopus_vulgaris                 Machabee
# Outgroup        No  Naupactus_xanthographus                Mauritius
# T-Reu_2316      No       Scaevinus_dombayae                  Bayonne
# T-Reu_2318      No       Scaevinus_dombayae                  Bayonne
# T-Reu_2320      No       Scaevinus_dombayae                  Bayonne
# T-Reu_2322      No       Scaevinus_dombayae                  Bayonne
# T-Reu_2323      No       Scaevinus_dombayae                  Bayonne
# T-Reu_2431      No       Scaevinus_dombayae      Plaine_des_Fougiers
# T-Reu_2922      No       Scaevinus_dombayae              Mare_Longue
# T-Reu_3051      No       Scaevinus_dombayae       Plaine_des_Gregues
# T-Reu_3785      No       Scaevinus_dombayae      Plaine_des_Fougiers
# T-Mau_130       No   Scaevinus_subtruncatus                   Florin
# T-Mau_245       No   Scaevinus_subtruncatus              Pigeon_wood
# T-Mau_3343      No   Scaevinus_subtruncatus           Vallee_de_lest
# T-Mau_3705      No   Scaevinus_subtruncatus                 Le_Pouce
# T-Mau_3706      No   Scaevinus_subtruncatus                 Le_Pouce
# T-Mau_3707      No   Scaevinus_subtruncatus                 Le_Pouce
# T-Mau_3843      No   Scaevinus_subtruncatus                Brise_Fer
# T-Mau_45        No   Scaevinus_subtruncatus         Montagne_Cocotte
# T-Mau_51        No   Scaevinus_subtruncatus         Montagne_Cocotte
# T-Mau_69        No   Scaevinus_subtruncatus                Brise_Fer
#
#                          Country                Island  \
# Sample
# T-Reu_2367                France        Reunion Island
# T-Reu_3153                France        Reunion Island
# T-Reu_3812                France        Reunion Island
# T-Reu_4047                France        Reunion Island
# T-Reu_4056                France        Reunion Island
# T-Reu_4057                France        Reunion Island
# T-Reu_4058                France        Reunion Island
# T-Reu_4343                France        Reunion Island
# T-Reu_4374                France        Reunion Island
# T-Reu_4396                France        Reunion Island
# T-Reu_4458                France        Reunion Island
# T-Reu_81                  France        Reunion Island
# T-Reu_3458                France        Reunion Island
# T-Reu_3459                France        Reunion Island
# T-Reu_3460                France        Reunion Island
# T-Reu_3462                France        Reunion Island
# T-Reu_3465                France        Reunion Island
# T-Reu_3467                France        Reunion Island
# T-Reu_3471                France        Reunion Island
# T-Reu_3522                France        Reunion Island
# T-Reu_3526                France        Reunion Island
# T-Reu_3530                France        Reunion Island
# T-Reu_3605                France        Reunion Island
# T-Reu_4265                France        Reunion Island
# T-Reu_3461                France        Reunion Island
# T-Reu_3491                France        Reunion Island
# T-Reu_4918                France        Reunion Island
# T-Reu_80                  France        Reunion Island
# T-Reu_225                 France        Reunion Island
# T-Reu_227                 France        Reunion Island
# ...                          ...                   ...
# T-Mau_3890             Mauritius             Mauritius
# T-Mau_3894             Mauritius             Mauritius
# T-Mau_3895             Mauritius             Mauritius
# T-Reu_3785  T-Reu_3785_Scaevinus_dombayae_(Plaine_des_Foug...   Blue
# T-Mau_130   T-Mau_130_Scaevinus_subtruncatus_(Florin-Mauri...    red
# T-Mau_245   T-Mau_245_Scaevinus_subtruncatus_(Pigeon_wood-...    red
# T-Mau_3343  T-Mau_3343_Scaevinus_subtruncatus_(Vallee_de_l...    red
# T-Mau_3705  T-Mau_3705_Scaevinus_subtruncatus_(Le_Pouce-Ma...    red
# T-Mau_3706  T-Mau_3706_Scaevinus_subtruncatus_(Le_Pouce-Ma...    red
# T-Mau_3707  T-Mau_3707_Scaevinus_subtruncatus_(Le_Pouce-Ma...    red
# T-Mau_3843  T-Mau_3843_Scaevinus_subtruncatus_(Brise_Fer-M...    red
# T-Mau_45    T-Mau_45_Scaevinus_subtruncatus_(Montagne_Coco...    red
# T-Mau_51    T-Mau_51_Scaevinus_subtruncatus_(Montagne_Coco...    red
# T-Mau_69    T-Mau_69_Scaevinus_subtruncatus_(Brise_Fer-Mau...    red
#
#                                   clade
# Sample
# T-Reu_2367    Reunion Cratopopsis group
# T-Reu_3153    Reunion Cratopopsis group
# T-Reu_3812    Reunion Cratopopsis group
# T-Reu_4047    Reunion Cratopopsis group
# T-Reu_4056    Reunion Cratopopsis group
# T-Reu_4057    Reunion Cratopopsis group
# T-Reu_4058    Reunion Cratopopsis group
# T-Reu_4343    Reunion Cratopopsis group
# T-Reu_4374    Reunion Cratopopsis group
# T-Reu_4396    Reunion Cratopopsis group
# T-Reu_4458    Reunion Cratopopsis group
# T-Reu_81      Reunion Cratopopsis group
# T-Reu_3458    Reunion Cratopopsis group
# T-Reu_3459    Reunion Cratopopsis group
# T-Reu_3460    Reunion Cratopopsis group
# T-Reu_3462    Reunion Cratopopsis group
# T-Reu_3465    Reunion Cratopopsis group
# T-Reu_3467    Reunion Cratopopsis group
# T-Reu_3471    Reunion Cratopopsis group
# T-Reu_3522    Reunion Cratopopsis group
# T-Reu_3526    Reunion Cratopopsis group
# T-Reu_3530    Reunion Cratopopsis group
# T-Reu_3605    Reunion Cratopopsis group
# T-Reu_4265    Reunion Cratopopsis group
# T-Reu_3461  Mauritius Cratopopsis group
# T-Reu_3491  Mauritius Cratopopsis group
# T-Reu_4918  Mauritius Cratopopsis group
# T-Reu_80    Mauritius Cratopopsis group
# T-Reu_225     Reunion Cratopopsis group
# T-Reu_227     Reunion Cratopopsis group
# ...                                 ...
# T-Mau_3890    Cratopus aeneoniger group
# T-Mau_3894    Cratopus aeneoniger group
# T-Mau_3895    Cratopus aeneoniger group
# T-Mau_3918    Cratopus aeneoniger group
# T-Mau_3921    Cratopus aeneoniger group
# T-Mau_3922    Cratopus aeneoniger group
# T-Mau_3923    Cratopus aeneoniger group
# T-Mau_73      Cratopus aeneoniger group
# T-Mau_84      Cratopus aeneoniger group
# T-Mau_93      Cratopus aeneoniger group
# Outgroup                       outgroup
# T-Reu_2316           Scaevinus dombayae
# T-Reu_2318           Scaevinus dombayae
# T-Reu_2320           Scaevinus dombayae
# T-Reu_2322           Scaevinus dombayae
# T-Reu_2323           Scaevinus dombayae
# T-Reu_2431           Scaevinus dombayae
# T-Reu_2922           Scaevinus dombayae
# T-Reu_3051           Scaevinus dombayae
# T-Reu_3785           Scaevinus dombayae
# T-Mau_130        Scaevinus subtruncatus
# T-Mau_245        Scaevinus subtruncatus
# T-Mau_3343       Scaevinus subtruncatus
# T-Mau_3705       Scaevinus subtruncatus
# T-Mau_3706       Scaevinus subtruncatus
# T-Mau_3707       Scaevinus subtruncatus
# T-Mau_3843       Scaevinus subtruncatus
# T-Mau_45         Scaevinus subtruncatus
# T-Mau_51         Scaevinus subtruncatus
# T-Mau_69         Scaevinus subtruncatus
#
# [1187 rows x 8 columns]

# %%
set(metadata_df["Island"])
# Out:
# {'GenBank_(GU176345.1)', 'Mauritius', 'Reunion Island', 'Rodrigues Island'}

# %%
## Pack everything into a dictionary
data_dicts = {"Reunion Island":{}, "Mauritius":{}}
for i in data_dicts:
    data_dicts[i] = {x:[] for x in set(metadata_df[metadata_df["Island"] == i]["clade"])}

## Or do it separately. Either way works, lets see which is less annoying.
#reunion_clades = {x:[] for x in set(metadata_df[metadata_df["Island"] == "Reunion Island"]["clade"])}
#mauritius_clades = {x:[] for x in set(metadata_df[metadata_df["Island"] == "Mauritius"]["clade"])}
print(data_dicts)
# Out:
# {'Mauritius': {'Mauritius Cratopopsis group': [], 'Cratopus melanocephalus': [], 'Cratopus carei': [], 'Cratopus aeneoniger group': [], 'Cratopus murinus': [], 'Cratopus caliginosus': [], 'Cratopus molitor': [], 'Cratopus viridipunctatus': [], 'Scaevinus subtruncatus': [], 'Cratopus variegatus': [], 'Cratopus mundulus': [], 'Cratopus striga': [], 'Cratopus psittacus': [], 'Cratopus armatus': [], 'Cratopus nigrogranatus': [], 'Cratopus viridilimbatus': [], 'Cratopus ovalis': [], 'Cratopus fasciger': [], 'Cratopus punctum': []}, 'Reunion Island': {'Mauritius Cratopopsis group': [], 'Reunion Cratopopsis group': [], 'Cratopus sumptuosus': [], 'Cratopus septemvittatus': [], 'Cratopus nigridorsis group': [], 'Cratopus aeneoniger group': [], 'Cratopus nanus': [], 'Scaevinus dombayae': [], 'Cratopus humeralis group': [], 'Cratopus bernei': [], 'Cratopus ditissimus': [], 'Cratopus frapieri group': [], 'Cratopus murinus': [], 'Cratopus punctum': []}}

# %% [markdown]
# ## Sort sequences into clades per island

# %%
nexfile = "RAxML/Input/Supplementary_COII.nex"

lines = open(nexfile).readlines()
lines = lines[921:1831]
print(len(lines))

for line in lines:
    sample, sequence = line.strip().split()
    if metadata_df.loc[sample]["Island"] in ["GenBank_(GU176345.1)", "Rodrigues Island"]:
        continue
    data_dicts[metadata_df.loc[sample]["Island"]][metadata_df.loc[sample]["clade"]].append(line.strip())

abunds = {}
for d in data_dicts:
    abunds[d] = []
    print(d, len(data_dicts[d]))
    for i in data_dicts[d]:
        print(i, len(data_dicts[d][i]))
        abunds[d].append(len(data_dicts[d][i]))
    print("Numinds {} {}".format(d, sum(abunds[d])))
    print("\n")
# Out:
# 910
# ('Mauritius', 19)
# ('Mauritius Cratopopsis group', 9)
# ('Cratopus melanocephalus', 15)
# ('Cratopus carei', 5)
# ('Cratopus aeneoniger group', 96)
# ('Cratopus murinus', 70)
# ('Cratopus caliginosus', 42)
# ('Cratopus molitor', 1)
# ('Cratopus viridipunctatus', 1)
# ('Scaevinus subtruncatus', 10)
# ('Cratopus variegatus', 4)
# ('Cratopus mundulus', 4)
# ('Cratopus striga', 1)
# ('Cratopus psittacus', 6)
# ('Cratopus armatus', 14)
# ('Cratopus nigrogranatus', 3)
# ('Cratopus viridilimbatus', 25)
# ('Cratopus ovalis', 23)
# ('Cratopus fasciger', 1)
# ('Cratopus punctum', 13)
# Numinds Mauritius 343
#
#
# ('Reunion Island', 14)
# ('Mauritius Cratopopsis group', 4)
# ('Reunion Cratopopsis group', 93)
# ('Cratopus sumptuosus', 88)
# ('Cratopus septemvittatus', 3)
# ('Cratopus nigridorsis group', 14)
# ('Cratopus aeneoniger group', 22)
# ('Cratopus nanus', 97)
# ('Scaevinus dombayae', 9)
# ('Cratopus humeralis group', 77)
# ('Cratopus bernei', 4)
# ('Cratopus ditissimus', 7)
# ('Cratopus frapieri group', 101)
# ('Cratopus murinus', 15)
# ('Cratopus punctum', 5)
# Numinds Reunion Island 539

# %%
for i in abunds:
    print(i, entropy(abunds[i]))
# Out:
# ('Mauritius', 2.245779463443025)
# ('Reunion Island', 2.094381971099274)

# %% [markdown]
# ## Write sequences to fasta files per clade per island

# %%
fastadir = "weevil_fasta/"
reunion_dir = fastadir + "reunion/"
mauritius_dir = fastadir + "mauritius/"
dirs = {"Reunion Island":reunion_dir, "Mauritius":mauritius_dir}
if not os.path.exists(mauritius_dir):
    os.mkdir(fastadir)
    os.mkdir(reunion_dir)
    os.mkdir(mauritius_dir)
for i in data_dicts:
    print(i)
    for c in data_dicts[i]:
        clade_vcf = dirs[i] + c.replace(" ", "_") + ".fasta"
        with open(clade_vcf, 'w') as outfile:
            for samp in data_dicts[i][c]:
                name, seq = samp.split()
                outfile.write(">{}\n{}\n".format(name, seq))
# Out:
# Mauritius
# Reunion Island

# %% [markdown]
# ## Make observed SGD files

# %%
# !../make_obs.py -f weevil_fasta/mauritius/ -o mauritius.obs
# !../make_obs.py -f weevil_fasta/reunion/ -o reunion.obs

# %%
# !cat mauritius.obs
# !cat reunion.obs
# Out:
# 	bin_0	bin_1	bin_2	bin_3	bin_4	bin_5	bin_6	bin_7	bin_8	bin_9
# 4	5	1	6	1	0	0	0	1	1	bin_0	bin_1	bin_2	bin_3	bin_4	bin_5	bin_6	bin_7	bin_8	bin_9
# 0	4	2	3	3	0	0	1	0	1
